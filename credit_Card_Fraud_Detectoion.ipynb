# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
d=pd.read_csv("/content/drive/MyDrive/Datasets/creditcard.csv")

# %%
d.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
d.shape
# Out:
# (284807, 31)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
d.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
d['Class'].value_counts()
#here we can see that there are wayyy too many classifications of 0 in this data thus it is wayy more likely to classify an enty inot class 0 htan 1
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# Thus this data is highly unbalanced
#
# label 1=>fraudulant transaction
#
# label 0=>normal transaction

# %%
# we seperate the class 0 from the class 1
legit=d[d.Class==0]
fraud=d[d.Class==1]

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
d.groupby("Class").mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# #Building a sample data set with 492 legit values and 492 fraud values to make a good dataset

# %%
legit_sample=legit.sample(n=492)

# %% [markdown]
# #concatinate the samples

# %%
new_d=pd.concat([legit_sample,fraud],axis=0)
new_d.shape
# Out:
# (984, 31)

# %%
new_d.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 27850    34733.0  0.137023 -2.027368 -0.750829  0.533548 -0.953187 -0.432748
# 37097    38805.0 -0.812982 -0.364265  2.708558 -1.910680 -1.091747 -0.628724
# 125927   77866.0 -0.517416  0.313686  1.537756 -1.558396  0.700028  1.288011
# 194757  130746.0 -0.755024 -0.349783  1.809383 -1.998107 -0.215220 -0.155462
# 203583  134876.0  2.031390 -0.124766 -0.912661  0.527122 -0.454803 -1.483329
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 27850   0.723326 -0.149296  0.255227  ...  0.275684 -0.538610 -0.634685
# 37097   0.324758 -0.241589 -0.210939  ... -0.135968  0.249129 -0.139072
# 125927  0.271898  0.507856  0.038740  ...  0.010926  0.338478  0.066529
# 194757 -0.319260  0.257476 -1.028064  ...  0.372152  0.844561 -0.446504
# 203583  0.114063 -0.295180  0.690926  ... -0.274968 -0.717972  0.406321
#
# ...

# %%
new_d.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_d["Class"].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_d.groupby("Class").mean()
#this step is v v imp 
#it helps us to figure out if out random selection is good since the values we get here should be close to the values we got on the entire dataset
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94796.128049 -0.001404  0.037909 -0.019055  0.012350  0.068256
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.001534 -0.037417  0.069716 -0.041250  ... -0.010229  0.001414
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.059169  0.005430  0.000216  0.048237 -0.028698  0.018555 -0.002753
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       77.728618
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X=new_d.drop(columns="Class",axis=1)
Y=new_d["Class"]

# %%
trainx,testx,trainy,testy=train_test_split(X,Y,random_state=2,test_size=0.2,stratify=Y)

# %%
#Logistic Regression
m1=LogisticRegression()

# %%
m1.fit(trainx,trainy)
# Out:
# LogisticRegression()

# %% [markdown]
# #Accuracy Score using Logistic Regression

# %%
predict_train1=m1.predict(trainx)
print("Accuracy Score of training data with Logistic Regression: ",accuracy_score(trainy,predict_train1))

predict_test1=m1.predict(testx)
print("Accuracy Score of testing data with Logistic Regression: ",accuracy_score(testy,predict_test1))
# Out:
# Accuracy Score of training data with Logistic Regression:  0.9148665819567979
# Accuracy Score of testing data with Logistic Regression:  0.8984771573604061

# %%
#RandomForestClassifier

m2=RandomForestClassifier()

# %%
m2.fit(trainx,trainy)
# Out:
# RandomForestClassifier()

# %% [markdown]
# #Accuracy Score using RandomForestClassfier

# %%
predict_train2=m2.predict(trainx)
print("Accuracy Score of training data with RandomForestClassifier: ",accuracy_score(trainy,predict_train2))

predict_test2=m2.predict(testx)
print("Accuracy Score of testing data with RandomForestClassifier: ",accuracy_score(testy,predict_test2))
# Out:
# Accuracy Score of training data with RandomForestClassifier:  1.0
# Accuracy Score of testing data with RandomForestClassifier:  0.9187817258883249

# %% [markdown]
# #Prediction System

# %%
input=(np.asarray((2,-1.15823309349523,0.877736754848451,1.548717846511,0.403033933955121,-0.407193377311653,0.0959214624684256,0.592940745385545,-0.270532677192282,0.817739308235294,0.753074431976354,-0.822842877946363,0.53819555014995,1.3458515932154,-1.11966983471731,0.175121130008994,-0.451449182813529,-0.237033239362776,-0.0381947870352842,0.803486924960175,0.408542360392758,-0.00943069713232919,0.79827849458971,-0.137458079619063,0.141266983824769,-0.206009587619756,0.502292224181569,0.219422229513348,0.215153147499206,69.99))).reshape(1,-1)
if(m2.predict(input)):
  print("Fraudulant statement")
else:
  print("Legitimate Stetement")
# Out:
# Legitimate Stetement
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
input=(np.asarray((47545,1.17671575912859,0.557090903443645,-0.490799622910899,0.756424293386678,0.2491915585394,-0.781870546568533,0.228750322026116,-0.0408400791377636,-0.432110564245139,-0.585778431385528,2.28193937592012,0.654566719272309,-0.310379432324912,-1.04370522504569,0.513750399321109,0.399177755263914,1.14313007770305,0.256013886486252,-0.511210088142662,-0.10277180482264,-0.0621660000083396,-0.128168129786567,-0.0401759895545737,0.110040347467026,0.437891432381746,0.368808854483266,-0.0182873480981415,0.0311734033163997,0.76))).reshape(1,-1)
if(m2.predict(input)):
  print("Fraudulant statement")
else:
  print("Legitimate Stetement")
# Out:
# Fraudulant statement
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
